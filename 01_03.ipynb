# %% [markdown]
# <a href="https://colab.research.google.com/github/QutubkhanKheraluwala/Pytorch/blob/Colab/01_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q "google-generativeai>=0.7.2"
import google.generativeai as genai
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('models/gemini-1.5-flash')
response = model.generate_content("Please give me python code to sort a list.")
print(response.text)
# Out:
# ```python
# # Method 1: Using the built-in sort() method
# my_list = [5, 2, 9, 1, 7]
# my_list.sort()  # Sorts the list in ascending order
# print(my_list)  # Output: [1, 2, 5, 7, 9]
#
# # Method 2: Using the sorted() function
# my_list = [5, 2, 9, 1, 7]
# sorted_list = sorted(my_list)  # Returns a new sorted list
# print(sorted_list)  # Output: [1, 2, 5, 7, 9]
# print(my_list)  # Output: [5, 2, 9, 1, 7] (Original list remains unchanged)
#
# # Method 3: Sorting in descending order
# my_list = [5, 2, 9, 1, 7]
# my_list.sort(reverse=True)  # Sorts in descending order
# print(my_list)  # Output: [9, 7, 5, 2, 1]
#
# # Method 4: Using a custom sorting function (for complex sorting logic)
# my_list = ['apple', 'banana', 'cherry', 'date']
# my_list.sort(key=len)  # Sorts based on the length of each string
# print(my_list)  # Output: ['date', 'apple', 'banana', 'cherry']
# ```
#
# **Explanation:**
#
# 1. **`sort()` method:** This method modifies the original list in-place. You can pass `reverse=True` as an argument to sort in descending order.
# 2. **`sorted()` function:** This function returns a new sorted list without modifying the original list. You can use it to maintain the original list while creating a sorted copy.
# 3. **Custom Sorting Function:** You can define a custom function to specify how you want to sort the list. This is useful for more complex sorting logic, like sorting by multiple criteria.
#
# Choose the method that best suits your needs based on whether you need to modify the original list, need a new sorted list, or want to apply custom sorting logic.

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.4.1+cu121
# True
